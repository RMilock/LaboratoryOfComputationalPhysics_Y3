# %% [markdown]
# ### Plotting Udine Temperature

# %%
import pandas as pd
import numpy as np
file_name="/home/hal20/MEGAsync/Padova/Physics/Physics2.0/Tesi/RiccardoTesi/udine_outdoor_14_21_input.csv"
data = pd.read_csv(file_name, sep = ";", header = None)
#data=pd.read_csv(file_name)
data.rename(columns={0:'Date',
                          2:'T1',
                          3:'T2'}, 
                 inplace=True)
del data[1]; del data[4]
for i in range(len(data)):
    if data["Date"][i] < 2002000000:
        data1=data
    else: break
data1
# Out:
#             Date  T1  T2
# 0     2001010121   2   0
# 1     2001010214   5   0
# 2     2001010221   5   0
# 3     2001010414   8   0
# 4     2001010421   7   0
# ...          ...  ..  ..
# 8343  2017021521   6   1
# 8344  2017021614  17   6
# 8345  2017021621   6   3
# 8346  2017021714   7   3
# 8347  2017021721   7   2
#
# [8348 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

#creating normally distr 4 datasets
data1.plot(x='Date', y='T1', style='*')
#pdf=pd.DataFrame(data, index=, columns=['T1', 'T2'])
#print(pdf)
#pdf = pdf.cumsum() #move on rows but sum over columns
#data.plot(); 
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-1b4b7223fae2> in <module>
#       2
#       3 #creating normally distr 4 datasets
# ----> 4 data1.plot(x='Date', y='T1', style='*')
# ...
